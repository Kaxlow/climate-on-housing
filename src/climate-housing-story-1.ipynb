# %% [markdown]
# # Climate Housing Story 1 Data
#
# Generates only the data assets used by `output/visualizations/climate-housing-story-1.html`, then serves that page locally.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'data').exists():
    ROOT = ROOT.parent
SRC_DIR = ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from climate_housing_page_utils import build_and_serve

# %%
result = build_and_serve('story-1', 'climate-housing-story-1.html')
result['url']
